# %% [markdown]
# ### Kellie Bernhardt Final Exam
# Applied Machine Learning

# %% [markdown]
# Read in data

# %%
import pandas as pd
auto = pd.read_csv("auto-mpg.csv")
auto.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Train/Test Data Split

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(auto, 
                        test_size=0.2, random_state=123)
print('Train size: ', len(train_set), 'Test size: ', len(test_set))
# Out:
# Train size:  318 Test size:  80

# %% [markdown]
# Set X and y features, train Linear Regression model, and output Linear Regression model metrics

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

X = train_set[['displacement','weight']]
y = train_set['mpg']

lr_model = LinearRegression()
lr_model.fit(X,y)

y_pred = lr_model.predict(X)
print('Results for linear regression on training data')
print(' Default settings')
print('Internal parameters:')
print(' Bias is ', lr_model.intercept_)
print(' Coefficients', lr_model.coef_)
print(' Score', lr_model.score(X,y))
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2 ', r2_score(y,y_pred))
# Out:
# Results for linear regression on training data
#  Default settings
# Internal parameters:
#  Bias is  43.6214339764433
#  Coefficients [-0.01801839 -0.00556012]
#  Score 0.7024820582511935
# MAE is  3.2290037032091616
# RMSE is  4.2789696537676765
# MSE is  18.309581297864668
# R^2  0.7024820582511935

# %% [markdown]
# Pipelined linear regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler


X = train_set[['displacement','origin']]
y = train_set['mpg']

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
poly3 = PolynomialFeatures(degree=3, include_bias=False)
#poly3 will be turned on for poly nomial features
scale = StandardScaler()
lr_model = LinearRegression()

stages = [('imp_mean', imp_mean),('scale', scale),('lr_model', lr_model),]
#stages = [('imp_mean', imp_mean),('poly3', poly3),('scale', scale),('lr_model', lr_model),]
pipe_model = Pipeline(stages)

lr_model = LinearRegression()
pipe_model.fit(X,y)

y_pred = pipe_model.predict(X)
print('Results for pipeline linear regression on training data')
#print('  Default settings')
#print('Internal parameters:')
print('   Bias is ', pipe_model.predict(X))
#print('   Coefficients', lr_model.coef_)
print('   Score', pipe_model.score(X,y))

print('MAE is  ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2    ', r2_score(y,y_pred))
# Out:
# Results for pipeline linear regression on training data
#    Bias is  [13.97077653 29.39673491  7.77338734 30.19543661 26.87808583 29.81558673
#  20.06431709 28.11248865  7.67531168 27.25978177 21.18933311 13.9488587
#  26.09093009 28.5221102  16.70772956 19.57508042 27.39894023 29.83589332
#  14.07808245 29.84327753 19.43199503 16.0165686  26.50746622 11.0665046
#  21.23894174 14.04116138 29.42096842 26.85593319 13.97839556 28.89249499
#  16.98765773 23.29050679 13.99477523 27.158014   15.9888778  27.93664393
#  16.00364623 21.17986803 28.15125577 29.81374067 13.44807608  9.2837914
#  28.14940972 21.59871985 29.39327762 29.50404083 28.00518272 28.89434105
#  28.05133406 28.55533916 28.49257334 31.17367513  8.59263044 19.59723306
#  29.84881569 20.12892896 20.10123816 16.93966033 31.0109876  29.02057714
#  25.89776644 21.63748697 30.75136602  9.25610059 29.44312106 29.29657838
#  29.31758942 29.97850908 28.0974854  19.51738313 17.04119328 28.51103388
# ...
